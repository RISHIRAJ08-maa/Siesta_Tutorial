# %% [markdown]
# # SIESTA Exercise 1 – First CH₄ Calculation
#
# This notebook runs a basic SIESTA calculation for methane (CH₄)
# using the tutorial inputs.

# %%
# %cd ~/siesta-docs/work-files/tutorials/basic/first-encounter/01-CH4-Basic
# Out:
# /home/l-rishiraj/siesta-docs/work-files/tutorials/basic/first-encounter/01-CH4-Basic

# %%
mkdir -p exercise_1

# %%
cp ch4.fdf C.psml H.psml exercise_1/

# %%
# %cd exercise_1
# Out:
# /home/l-rishiraj/siesta-docs/work-files/tutorials/basic/first-encounter/01-CH4-Basic/exercise_1

# %%
ls
# Out:
# ch4.fdf  C.psml  H.psml

# %%
# !siesta ch4.fdf > ch4.out
# Out:
# Job completed

# %%
# !grep "SCF cycle converged" ch4.out
# Out:
# SCF cycle converged after 6 iterations

# %%
# !grep "Total =" ch4.out
# Out:
# siesta:         Total =    -222.538221

# %%
ls
# Out:
# 0_NORMAL_EXIT          ch4.DM        ch4.STRUCT_OUT               FORCE_STRESS
# BASIS_ENTHALPY         ch4.EIG       ch4.XV                       H.ion
# BASIS_HARRIS_ENTHALPY  ch4.FA        C.ion                        H.ion.nc
# ch4.alloc              ch4.fdf       C.ion.nc                     H.ion.xml
# ch4.BASIS_ENTHALPY     ch4.HSX       C.ion.xml                    H.psml
# ch4.bib                ch4.KP        CLOCK                        MESSAGES
# ch4.BONDS              ch4.ORB_INDX  C.psml                       OUTVARS.yml
# ch4.BONDS_FINAL        ch4.out       fdf.20260102T164749.399.log  PARALLEL_DIST
