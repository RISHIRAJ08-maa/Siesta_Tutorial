# %% [markdown]
# # Check the result with water dimer

# %% [markdown]
# We will use the same input files as before, but now we will be using the optimized basis set with the PAO.Basis block we get at last tutorial.

# %% [raw]
# %block PAO.Basis
#   H 1
#     n=1 0 2 P 1
#         4.5 2.0
#   O 2
#     n=2 0 2
#         5.5 3.0
#     n=2 1 2 P 1
#         7.0 3.0
# %endblock PAO.Basis

# %% [markdown]
# The above PAO.Basis block is found after the optimization of single zeta and optimization of double zeta

# %%
# !pwd
# Out:
# /home/l-rishiraj/siesta-docs/work-files/tutorials/basic/basis-optimization/05-OptimizedWaterDimer

# %%
# !ls
# Out:
#  dimer.fdf   H.psml   monomer.fdf   O.psml  'Tutorial 2 Ex 5.ipynb'

# %%
# !mkdir run3

# %%
# !cp dimer.fdf   H.psml   monomer.fdf   O.psml run3/

# %%
# !ls run3
# Out:
# dimer.fdf  H.psml  monomer.fdf	O.psml

# %%
# %cd run3
# Out:
# /home/l-rishiraj/siesta-docs/work-files/tutorials/basic/basis-optimization/05-OptimizedWaterDimer/run3
# /home/l-rishiraj/miniconda3/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !siesta < monomer.fdf > monomer.out
# !siesta < dimer.fdf   > dimer.out
# Out:
# Job completed
# Job completed

# %%
# !grep "Total =" monomer.out
# !grep "Total =" dimer.out
# Out:
# siesta:         Total =    -482.936001
# siesta:         Total =    -966.119097

# %% [markdown]
# Now the binding energy is approx -247 MeV, which is lower than run2 and almost double times reduces than run_1 of (Tutorial2Ex2). This binding energy is get after finding the minimum cutoff radii and matching radii of each element in water molecules.Again to get best quality result , we need to optimize the remaining parameter ,i.e polarization orbital.
